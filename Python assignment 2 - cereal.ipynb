# %% [markdown]
# ### Python Assignment 2

# %%
#Task 1: Load pandas, seaborn and metplotlib
import pandas as pd 
import seaborn as sns # for data visualisation and basic plotting
import matplotlib.pyplot as plt # another library for data visualisation

# %%
# Task 2: Read the data file 
df =  pd.read_csv('cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
# Task 3: Inspect the data frame using frequently used functions.

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
# Task 4: Using mfr: Manufacturer of cereal columns find the number of cereal per manufacturer

#num_of_cereals = df.groupby('mfr').nunique()
num_of_cereals = df['mfr'].value_counts()
# Print the result
print("Number of cereals per manufacturer:")
print(num_of_cereals)
# Out:
# Number of cereals per manufacturer:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
#  Visualize it using count plot and pie chart.
sns.countplot(x = 'mfr', data = df)
# Out:
# <Axes: xlabel='mfr', ylabel='count'>

# %%
# pie chart
plt.pie(df['mfr'].value_counts(),labels=['K','G','P','Q','R','N','A'], autopct ='%1.2f%%')
plt.title('Pie chart for outcome')
# Out:
# Text(0.5, 1.0, 'Pie chart for outcome')

# %%
# Task 5: Create a Histogram for the distribution of calories
df.calories.hist(figsize=(5,5)) 
#df.hist(calories) 
  
# Set title 
plt.title("The distribution of calories") 
  
# adding labels 
#df.plot(x ='name',y = 'calories', kind ='hist')
# Out:
# Text(0.5, 1.0, 'The distribution of calories')

# %%
# Task 6:Visualize the distribution of 'vitamins' content in cereals. You can use a histogram for this
df.vitamins.hist(figsize=(5,5))  
  
# Set title 
plt.title("The distribution of vitamins")
# Out:
# Text(0.5, 1.0, 'The distribution of vitamins')

# %%
# Task 7: Find the correlation matrix
col=['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','shelf','weight','cups','rating']
corr_matrix = df[col].corr()
corr_matrix
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %%
# Create a correlation heatmap.
col=['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','shelf','weight','cups','rating']
corr_heat = df[col].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_heat, annot=True)
# Out:
# <Axes: >

# %%
# Task 8: Find the correlation between Calories vs Protein.
corr_cal_vs_prot = df['calories'].corr(df['protein'])
corr_cal_vs_prot
# Out:
# 0.019066068232356924

# %%
# Visualize this using scatter plot.
scat_cal_vs_prot = df.plot(x ='calories',y = 'protein', kind ='scatter')
scat_cal_vs_prot
# Out:
# <Axes: xlabel='calories', ylabel='protein'>

# %%
# Challenge Task:
#Create Boxplot for the following columns:

# %%
#1.Calories
sns.boxplot(df[['calories']],orient = 'h')
# Out:
# <Axes: >

# %%
#2.Fiber
sns.boxplot(df[['fiber']],orient = 'h')
# Out:
# <Axes: >

# %%
#3.Sugars
sns.boxplot(df[['sugars']],orient = 'h')
# Out:
# <Axes: >

# %%
#4.Carbohydrates
sns.boxplot(df[['carbo']],orient = 'h')
# Out:
# <Axes: >

# %%
#Comment on the above boxplots, are there any outliers? Can you remove outliers?

#1.Calories - yes
#2.Fiber - yes
#3.Sugars - No
#4.Carbohydrates - yes 

calQ3 = 110
calQ1 = 100
fibQ3 = 3
fibQ1 = 1
carbQ3 = 17
carbQ1 = 12

calIQR = calQ3 - calQ1
calLW = calQ1 - 1.5 * calIQR
calLW
calRW = calQ3 + 1.5 * calIQR
calRW

fibIQR = fibQ3 - fibQ1
fibLW = fibQ1 - 1.5 * fibIQR
fibLW
fibRW = fibQ3 + 1.5 * fibIQR
fibRW

carbIQR = carbQ3 - carbQ1
carbLW = carbQ1 - 1.5 * carbIQR
carbLW
carbRW = carbQ3 + 1.5 * carbIQR
carbRW
# Out:
# 24.5
